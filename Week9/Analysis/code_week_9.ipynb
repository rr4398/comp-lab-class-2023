# %%
import MDAnalysis as md
import numpy as np
import matplotlib.pyplot as plt
from MDAnalysis.analysis import rdf

# List of universes
universes = [
    md.Universe("../Data/equil/kalj_T0.45_n360_v300_100000000_1.lammpstrj", "../Data/prod/kalj_T0.45_n360_v300_prod_100000000_1.unwrap.dcd", topology_format="LAMMPSDUMP"),
    md.Universe("../Data/equil/kalj_T0.475_n360_v300_30000000_1.lammpstrj", "../Data/prod/kalj_T0.475_n360_v300_prod_30000000_1.unwrap.dcd", topology_format="LAMMPSDUMP"),
    md.Universe("../Data/equil/kalj_T0.5_n360_v300_10000000_1.lammpstrj", "../Data/prod/kalj_T0.5_n360_v300_prod_10000000_1.unwrap.dcd", topology_format="LAMMPSDUMP"),
    md.Universe("../Data/equil/kalj_T0.55_n360_v300_3000000_1.lammpstrj", "../Data/prod/kalj_T0.55_n360_v300_prod_3000000_1.unwrap.dcd", topology_format="LAMMPSDUMP"),
    md.Universe("../Data/equil/kalj_T0.6_n360_v300_1000000_1.lammpstrj", "../Data/prod/kalj_T0.6_n360_v300_prod_1000000_1.unwrap.dcd", topology_format="LAMMPSDUMP"),
    md.Universe("../Data/equil/kalj_T0.65_n360_v300_350000_1.lammpstrj", "../Data/prod/kalj_T0.65_n360_v300_prod_350000_1.unwrap.dcd", topology_format="LAMMPSDUMP"),
    md.Universe("../Data/equil/kalj_T0.7_n360_v300_180000_1.lammpstrj", "../Data/prod/kalj_T0.7_n360_v300_prod_180000_1.unwrap.dcd", topology_format="LAMMPSDUMP"),
    md.Universe("../Data/equil/kalj_T0.8_n360_v300_150000_1.lammpstrj", "../Data/prod/kalj_T0.8_n360_v300_prod_150000_1.unwrap.dcd", topology_format="LAMMPSDUMP"),
    md.Universe("../Data/equil/kalj_T0.9_n360_v300_150000_1.lammpstrj", "../Data/prod/kalj_T0.9_n360_v300_prod_150000_1.unwrap.dcd", topology_format="LAMMPSDUMP"),
    md.Universe("../Data/equil/kalj_T1_n360_v300_50000_1.lammpstrj", "../Data/prod/kalj_T1_n360_v300_prod_50000_1.unwrap.dcd", topology_format="LAMMPSDUMP"),
    md.Universe("../Data/equil/kalj_T1.5_n360_v300_10000_1.lammpstrj", "../Data/prod/kalj_T1.5_n360_v300_prod_10000_1.unwrap.dcd", topology_format="LAMMPSDUMP")
]

# Define the particle types
type1_atoms = "type 1"
type2_atoms = "type 2"
# Out:
# /home/rr4398/.local/lib/python3.8/site-packages/numpy/core/getlimits.py:518: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /home/rr4398/.local/lib/python3.8/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)
# /home/rr4398/.local/lib/python3.8/site-packages/numpy/core/getlimits.py:518: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /home/rr4398/.local/lib/python3.8/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)
# ...

# %%
temperatures = [0.475, 0.5, 0.55, 0.6, 0.65, 0.7, 0.8, 0.9, 1.0, 1.5]

plt.figure(figsize=(15, 12))

for i, temp in enumerate(temperatures):
    # Assuming each temperature corresponds to one universe, you can use indexing
    current_universe = universes[i]

    type1 = current_universe.select_atoms("type 1")
    type2 = current_universe.select_atoms("type 2")
    rdf_11 = rdf.InterRDF(type1, type1).run()
    
    # Plot RDF for the current temperature
    plt.plot(rdf_11.bins, rdf_11.rdf, label=f'Temp: {temp}')

plt.title('Radial Distribution Function', fontsize=13)
plt.xlabel('Distance in nm',fontsize=17)
plt.ylabel('Radial for g_11(r)', fontsize=17)
plt.legend(fontsize=15)
plt.savefig('RDF_g11.pdf', format='pdf')
plt.show()
# Out:
# /home/rr4398/.local/lib/python3.8/site-packages/MDAnalysis/analysis/rdf.py:316: DeprecationWarning: The `bins` attribute was deprecated in MDAnalysis 2.0.0 and will be removed in MDAnalysis 3.0.0. Please use `results.bins` instead
#   warnings.warn(wmsg, DeprecationWarning)
# /home/rr4398/.local/lib/python3.8/site-packages/MDAnalysis/analysis/rdf.py:324: DeprecationWarning: The `rdf` attribute was deprecated in MDAnalysis 2.0.0 and will be removed in MDAnalysis 3.0.0. Please use `results.rdf` instead
#   warnings.warn(wmsg, DeprecationWarning)
# /home/rr4398/.local/lib/python3.8/site-packages/MDAnalysis/analysis/rdf.py:316: DeprecationWarning: The `bins` attribute was deprecated in MDAnalysis 2.0.0 and will be removed in MDAnalysis 3.0.0. Please use `results.bins` instead
#   warnings.warn(wmsg, DeprecationWarning)
# ...

# %%
# Plotting RDFs for different temperatures
temperatures = [0.475, 0.5, 0.55, 0.6, 0.65, 0.7, 0.8, 0.9, 1.0, 1.5]

plt.figure(figsize=(15, 12))

for i, temp in enumerate(temperatures):
    # Assuming each temperature corresponds to one universe, you can use indexing
    current_universe = universes[i]

    type1 = current_universe.select_atoms("type 1")
    type2 = current_universe.select_atoms("type 2")
    rdf_12 = rdf.InterRDF(type1, type2).run()
    
    # Plot RDF for the current temperature
    plt.plot(rdf_12.bins, rdf_12.rdf, label=f'Temp: {temp}')

plt.title('Radial Distribution Function')
plt.xlabel('Distance in nm', fontsize=17)
plt.ylabel('Radial for g_12(r)', fontsize=17)
plt.legend(fontsize=15)
plt.savefig('RDF_g12.pdf',format='pdf')
plt.show()
# Out:
# /home/rr4398/.local/lib/python3.8/site-packages/MDAnalysis/analysis/rdf.py:316: DeprecationWarning: The `bins` attribute was deprecated in MDAnalysis 2.0.0 and will be removed in MDAnalysis 3.0.0. Please use `results.bins` instead
#   warnings.warn(wmsg, DeprecationWarning)
# /home/rr4398/.local/lib/python3.8/site-packages/MDAnalysis/analysis/rdf.py:324: DeprecationWarning: The `rdf` attribute was deprecated in MDAnalysis 2.0.0 and will be removed in MDAnalysis 3.0.0. Please use `results.rdf` instead
#   warnings.warn(wmsg, DeprecationWarning)
# /home/rr4398/.local/lib/python3.8/site-packages/MDAnalysis/analysis/rdf.py:316: DeprecationWarning: The `bins` attribute was deprecated in MDAnalysis 2.0.0 and will be removed in MDAnalysis 3.0.0. Please use `results.bins` instead
#   warnings.warn(wmsg, DeprecationWarning)
# ...

# %%
# Plotting RDFs for different temperatures
temperatures = [0.475, 0.5, 0.55, 0.6, 0.65, 0.7, 0.8, 0.9, 1.0, 1.5]

plt.figure(figsize=(15, 10))

for i, temp in enumerate(temperatures):
    # Assuming each temperature corresponds to one universe, you can use indexing
    current_universe = universes[i]

    type1 = current_universe.select_atoms("type 1")
    type2 = current_universe.select_atoms("type 2")
    rdf_22 = rdf.InterRDF(type2, type2).run()
    
    # Plot RDF for the current temperature
    plt.plot(rdf_22.bins, rdf_22.rdf, label=f'Temp: {temp}')

plt.title('Radial Distribution Function')
plt.xlabel('Distance in nm', fontsize=17)
plt.ylabel('Radial for g_22(r)', fontsize=17)
plt.legend(fontsize=15)
plt.savefig('RDF_g22.pdf',format='pdf')
plt.show()
# Out:
# /home/rr4398/.local/lib/python3.8/site-packages/MDAnalysis/analysis/rdf.py:316: DeprecationWarning: The `bins` attribute was deprecated in MDAnalysis 2.0.0 and will be removed in MDAnalysis 3.0.0. Please use `results.bins` instead
#   warnings.warn(wmsg, DeprecationWarning)
# /home/rr4398/.local/lib/python3.8/site-packages/MDAnalysis/analysis/rdf.py:324: DeprecationWarning: The `rdf` attribute was deprecated in MDAnalysis 2.0.0 and will be removed in MDAnalysis 3.0.0. Please use `results.rdf` instead
#   warnings.warn(wmsg, DeprecationWarning)
# /home/rr4398/.local/lib/python3.8/site-packages/MDAnalysis/analysis/rdf.py:316: DeprecationWarning: The `bins` attribute was deprecated in MDAnalysis 2.0.0 and will be removed in MDAnalysis 3.0.0. Please use `results.bins` instead
#   warnings.warn(wmsg, DeprecationWarning)
# ...

# %%
import MDAnalysis as md
import numpy as np
import matplotlib.pyplot as plt
from MDAnalysis.analysis import msd

# List of universes
universes = [
    md.Universe("../Data/equil/kalj_T0.45_n360_v300_100000000_1.lammpstrj", "../Data/prod/kalj_T0.45_n360_v300_prod_100000000_1.unwrap.dcd", topology_format="LAMMPSDUMP"),
    md.Universe("../Data/equil/kalj_T0.475_n360_v300_30000000_1.lammpstrj", "../Data/prod/kalj_T0.475_n360_v300_prod_30000000_1.unwrap.dcd", topology_format="LAMMPSDUMP"),
    md.Universe("../Data/equil/kalj_T0.5_n360_v300_10000000_1.lammpstrj", "../Data/prod/kalj_T0.5_n360_v300_prod_10000000_1.unwrap.dcd", topology_format="LAMMPSDUMP"),
    md.Universe("../Data/equil/kalj_T0.55_n360_v300_3000000_1.lammpstrj", "../Data/prod/kalj_T0.55_n360_v300_prod_3000000_1.unwrap.dcd", topology_format="LAMMPSDUMP"),
    md.Universe("../Data/equil/kalj_T0.6_n360_v300_1000000_1.lammpstrj", "../Data/prod/kalj_T0.6_n360_v300_prod_1000000_1.unwrap.dcd", topology_format="LAMMPSDUMP"),
    md.Universe("../Data/equil/kalj_T0.65_n360_v300_350000_1.lammpstrj", "../Data/prod/kalj_T0.65_n360_v300_prod_350000_1.unwrap.dcd", topology_format="LAMMPSDUMP"),
    md.Universe("../Data/equil/kalj_T0.7_n360_v300_180000_1.lammpstrj", "../Data/prod/kalj_T0.7_n360_v300_prod_180000_1.unwrap.dcd", topology_format="LAMMPSDUMP"),
    md.Universe("../Data/equil/kalj_T0.8_n360_v300_150000_1.lammpstrj", "../Data/prod/kalj_T0.8_n360_v300_prod_150000_1.unwrap.dcd", topology_format="LAMMPSDUMP"),
    md.Universe("../Data/equil/kalj_T0.9_n360_v300_150000_1.lammpstrj", "../Data/prod/kalj_T0.9_n360_v300_prod_150000_1.unwrap.dcd", topology_format="LAMMPSDUMP"),
    md.Universe("../Data/equil/kalj_T1_n360_v300_50000_1.lammpstrj", "../Data/prod/kalj_T1_n360_v300_prod_50000_1.unwrap.dcd", topology_format="LAMMPSDUMP"),
    md.Universe("../Data/equil/kalj_T1.5_n360_v300_10000_1.lammpstrj", "../Data/prod/kalj_T1.5_n360_v300_prod_10000_1.unwrap.dcd", topology_format="LAMMPSDUMP")
]

def compute_msd(atom_group, prd_data):
    type1 = prd_data.select_atoms(atom_group)
    msd1 = msd.EinsteinMSD(type1).run()
    return msd1

# Define the particle type
type1_atoms = "type 1"

# Compute MSD for type 1 particles at each temperature
temperatures = [0.475, 0.5, 0.55, 0.6, 0.65, 0.7, 0.8, 0.9, 1.0, 1.5]  # Add your temperatures here
time_msd_1={}
plt.figure(figsize=(15, 10))
for i, temp in enumerate(temperatures):
    # Assuming each temperature corresponds to one universe, you can use indexing
    current_universe = universes[i]

    # Compute RDF for the specific temperature
    msd_dict = compute_msd(type1_atoms, current_universe)

    # Plot RDF for the current temperature
    plt.loglog(msd_dict.times, msd_dict.run().results['msds_by_particle'].mean(axis=1), label=f'Temp: {temp}')
    # Find the time where MSD = 1
    time_msd_1[i] = msd_dict.times[np.argmax(msd_dict.run().results['msds_by_particle'].mean(axis=1) >= 1)]

plt.title('Mean-Squared Displacement')
plt.xlabel('Time', fontsize=22)
plt.ylabel('Mean Sq. Dis',fontsize=22)
plt.legend(fontsize=15)
#plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.savefig('MSD1.pdf',format='pdf')
plt.show()
# Out:
# /home/rr4398/.local/lib/python3.8/site-packages/MDAnalysis/topology/LAMMPSParser.py:631: UserWarning: Guessed all Masses to 1.0
#   warnings.warn('Guessed all Masses to 1.0')
# /home/rr4398/.local/lib/python3.8/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"

# %%
# Convert temperatures and time_msd_1 to numpy arrays
temperatures_np = np.array(temperatures)
time_msd_1_np = np.array(list(time_msd_1.values()))
plt.figure(figsize=(13, 9))
# Plotting log-log scale
plt.loglog(1 / temperatures_np, time_msd_1_np, marker='o', linestyle='-', color='g', label='Time where MSD=1')

plt.title('Time~ MSD=1 vs Temp$^{-1}$',fontsize=20)
plt.xlabel('Temp$^{-1}$',fontsize=17)
plt.ylabel('Time~ MSD=1',fontsize=17)
plt.legend(fontsize=15)
plt.savefig('time_temp.pdf', format='pdf')
plt.show()
